# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Train3 = pd.read_excel("Data_Train.xlsx")

# %%
Test3= pd.read_excel("Data_Test.xlsx")

# %%
Train3.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
Test3.head(100)
# Out:
#                                          Name    Location  Year  \
# 0                     Maruti Alto K10 LXI CNG       Delhi  2014
# 1               Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2   Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                        Toyota Etios Liva GD   Hyderabad  2012
# 4                           Hyundai i20 Magna      Mumbai  2014
# ..                                        ...         ...   ...
# 95                        Maruti Baleno Alpha       Kochi  2017
# 96              Honda Accord 2.4 Elegance M/T       Kochi  2011
# 97                        Nissan Micra XL CVT   Hyderabad  2018
# 98                Maruti Zen Estilo LXI BS IV        Pune  2011
# 99                    Hyundai Elantra CRDi SX     Kolkata  2013
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0               40929       CNG       Manual      First  32.26 km/kg   998 CC
# ...

# %% [raw]
# #We will directly start performing Data pre-Processing,
#
# Splitting name into Brand and Model columns

# %%
names = list(Train3.Name)
brand = []
model = []
for i in range(len(names)):
    try:
        brand.append(names[i].split(" ")[0].strip())
        try:
            model.append(" ".join(names[i].split(" ")[1:]).strip())
        except:
            pass
    except:
        print("ERR ! - ", names[i], "@" , i)
Train3["Brand"] =  brand
Train3["Model"] = model

# %%
names = list(Test3.Name)
brand = []
model = []
for i in range(len(names)):
    try:
        brand.append(names[i].split(" ")[0].strip())
        try:
            model.append(" ".join(names[i].split(" ")[1:]).strip())
        except:
            pass
    except:
        print("ERR ! - ", names[i], "@" , i)
Test3["Brand"] =  brand
Test3["Model"] = model

# %%
Test3.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price    Brand                               Model
# ...

# %%
Train3.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price    Brand                       Model
# ...

# %%
Train3= Train3.drop(['Name', 'New_Price'], axis =1)

# %%
Test3= Test3.drop(['Name', 'New_Price'], axis =1)

# %% [raw]
# #Now we will clean Mileage, Engine, Power columns because they have text along with numeric, We just want numeric Hence we will Remove the text from these columns

# %%
#Removing Texts from this column

mileage = list(Train3.Mileage)
for i in range(len(mileage)):
    try :
        mileage[i] = float(mileage[i].split(" ")[0].strip())
    except:
        mileage[i] = np.nan
Train3['Mileage'] = mileage

# %%
#Removing Texts from this column

mileage = list(Test3.Mileage)
for i in range(len(mileage)):
    try :
        mileage[i] = float(mileage[i].split(" ")[0].strip())
    except:
        mileage[i] = np.nan
Test3['Mileage'] = mileage

# %%
#Removing Texts from this column

Engine = list(Train3.Engine)
for i in range(len(Engine)):
    try :
        Engine[i] = float(Engine[i].split(" ")[0].strip())
    except:
        Engine[i] = np.nan
Train3['Engine'] = Engine

# %%
#Removing Texts from this column

Engine = list(Test3.Engine)
for i in range(len(Engine)):
    try :
        Engine[i] = float(Engine[i].split(" ")[0].strip())
    except:
        Engine[i] = np.nan
Test3['Engine'] = Engine

# %%
#Removing Texts from this column

Power = list(Train3.Power)
for i in range(len(Power)):
    try :
        Power[i] = float(Power[i].split(" ")[0].strip())
    except:
        Power[i] = np.nan
Train3['Power'] = Power

# %%
#Removing Texts from this column

Power = list(Test3.Power)
for i in range(len(Power)):
    try :
        Power[i] = float(Power[i].split(" ")[0].strip())
    except:
        Power[i] = np.nan
Test3['Power'] = Power

# %%
Train3.head()
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0      Mumbai  2010              72000       CNG       Manual      First
# 1        Pune  2015              41000    Diesel       Manual      First
# 2     Chennai  2011              46000    Petrol       Manual      First
# 3     Chennai  2012              87000    Diesel       Manual      First
# 4  Coimbatore  2013              40670    Diesel    Automatic     Second
#
#    Mileage  Engine   Power  Seats  Price    Brand                       Model
# 0    26.60   998.0   58.16    5.0   1.75   Maruti             Wagon R LXI CNG
# 1    19.67  1582.0  126.20    5.0  12.50  Hyundai    Creta 1.6 CRDi SX Option
# 2    18.20  1199.0   88.70    5.0   4.50    Honda                      Jazz V
# 3    20.77  1248.0   88.76    7.0   6.00   Maruti                  Ertiga VDI
# 4    15.20  1968.0  140.80    5.0  17.74     Audi  A4 New 2.0 TDI Multitronic

# %%
Test3.head()
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0       Delhi  2014              40929       CNG       Manual      First
# 1  Coimbatore  2013              54493    Petrol       Manual     Second
# 2      Mumbai  2017              34000    Diesel       Manual      First
# 3   Hyderabad  2012             139000    Diesel       Manual      First
# 4      Mumbai  2014              29000    Petrol       Manual      First
#
#    Mileage  Engine   Power  Seats    Brand                               Model
# 0    32.26   998.0   58.20    4.0   Maruti                    Alto K10 LXI CNG
# 1    24.70   796.0   47.30    5.0   Maruti              Alto 800 2016-2019 LXI
# 2    13.68  2393.0  147.80    7.0   Toyota  Innova Crysta Touring Sport 2.4 MT
# 3    23.59  1364.0     NaN    5.0   Toyota                       Etios Liva GD
# 4    18.50  1197.0   82.85    5.0  Hyundai                           i20 Magna

# %% [raw]
# Checking for null values if any

# %%
Train3.isnull().sum()
# Out:
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                36
# Power                143
# Seats                 42
# Price                  0
# Brand                  0
# Model                  0
# dtype: int64

# %%
Test3.isnull().sum()
# Out:
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine               10
# Power                32
# Seats                11
# Brand                 0
# Model                 0
# dtype: int64

# %% [raw]
# We will impute numeric columns by Median or mean and Categorical columns by Mode

# %%
Train3['Mileage']=Train3['Mileage'].fillna(Train3['Mileage'].mean())

Train3['Engine']=Train3['Engine'].fillna(Train3['Engine'].mean())


Train3['Power']=Train3['Power'].fillna(Train3['Power'].mean())

Train3['Seats']=Train3['Seats'].fillna(Train3['Seats'].mean())

# %%
Test3['Mileage']=Test3['Mileage'].fillna(Test3['Mileage'].mean())

Test3['Engine']=Test3['Engine'].fillna(Test3['Engine'].mean())


Test3['Power']=Test3['Power'].fillna(Test3['Power'].mean())

Test3['Seats']=Test3['Seats'].fillna(Test3['Seats'].mean())

# %%
Train3.isnull().sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Brand                0
# Model                0
# dtype: int64

# %%
Test3.isnull().sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Brand                0
# Model                0
# dtype: int64

# %%
#Encoding Categorical Variables
# I will be using Label encoder to encode this Ordinal Scale data Owner_Type

from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()
Train3['Owner_Type']= lb.fit_transform(Train3['Owner_Type'])

Test3['Owner_Type']= lb.fit_transform(Test3['Owner_Type'])

# %%
#let's check the number of categories are there-

Test3.Brand.value_counts()
# Out:
# Maruti           233
# Hyundai          233
# Honda            135
# Toyota            96
# Mercedes-Benz     62
# Volkswagen        59
# Mahindra          59
# Ford              51
# Audi              49
# BMW               45
# Tata              42
# Chevrolet         30
# Skoda             29
# Nissan            26
# Renault           25
# Fiat              10
# Mitsubishi         9
# Jaguar             8
# Land               7
# Volvo              7
# Mini               5
# Jeep               4
# Datsun             4
# ISUZU              1
# OpelCorsa          1
# Hindustan          1
# Bentley            1
# Isuzu              1
# Porsche            1
# Name: Brand, dtype: int64

# %%
#let's check the number of categories are there-

Test3.Fuel_Type.value_counts()
# Out:
# Diesel    647
# Petrol    579
# CNG         6
# LPG         2
# Name: Fuel_Type, dtype: int64

# %%
#let's check the number of categories are there-

Test3.Location.value_counts()
# Out:
# Mumbai        159
# Pune          143
# Coimbatore    136
# Hyderabad     134
# Kochi         121
# Kolkata       119
# Delhi         106
# Chennai        97
# Jaipur         86
# Bangalore      82
# Ahmedabad      51
# Name: Location, dtype: int64

# %%
Train3['Location']= lb.fit_transform(Train3['Location'])

Train3['Fuel_Type']= lb.fit_transform(Train3['Fuel_Type'])

Train3['Brand']= lb.fit_transform(Train3['Brand'])

Train3['Transmission']= lb.fit_transform(Train3['Transmission'])

Train3['Model']= lb.fit_transform(Train3['Model'])


Test3['Location']= lb.fit_transform(Test3['Location'])

Test3['Fuel_Type']= lb.fit_transform(Test3['Fuel_Type'])

Test3['Brand']= lb.fit_transform(Test3['Brand'])

Test3['Transmission']= lb.fit_transform(Test3['Transmission'])

Test3['Model']= lb.fit_transform(Test3['Model'])

# %%
Train3.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         9  2010              72000          0             1           0
# 1        10  2015              41000          1             1           0
# 2         2  2011              46000          4             1           0
# 3         2  2012              87000          1             1           0
# 4         3  2013              40670          1             0           2
#
#    Mileage  Engine   Power  Seats  Price  Brand  Model
# 0    26.60   998.0   58.16    5.0   1.75     18   1643
# 1    19.67  1582.0  126.20    5.0  12.50     10    460
# 2    18.20  1199.0   88.70    5.0   4.50      9    911
# 3    20.77  1248.0   88.76    7.0   6.00     18    620
# 4    15.20  1968.0  140.80    5.0  17.74      1     96

# %%
Test3.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         4  2014              40929          0             1           0
# 1         3  2013              54493          3             1           2
# 2         9  2017              34000          1             1           0
# 3         5  2012             139000          1             1           0
# 4         9  2014              29000          3             1           0
#
#    Mileage  Engine      Power  Seats  Brand  Model
# 0    32.26   998.0   58.20000    4.0     16     70
# 1    24.70   796.0   47.30000    5.0     16     65
# 2    13.68  2393.0  147.80000    7.0     26    398
# 3    23.59  1364.0  110.38042    5.0     26    298
# 4    18.50  1197.0   82.85000    5.0      9    759

# %%
X=Train3.drop(['Price'], axis =1)

# %%
y= Train3.Price

# %%
X.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         9  2010              72000          0             1           0
# 1        10  2015              41000          1             1           0
# 2         2  2011              46000          4             1           0
# 3         2  2012              87000          1             1           0
# 4         3  2013              40670          1             0           2
#
#    Mileage  Engine   Power  Seats  Brand  Model
# 0    26.60   998.0   58.16    5.0     18   1643
# 1    19.67  1582.0  126.20    5.0     10    460
# 2    18.20  1199.0   88.70    5.0      9    911
# 3    20.77  1248.0   88.76    7.0     18    620
# 4    15.20  1968.0  140.80    5.0      1     96

# %%
y.head()
# Out:
# 0     1.75
# 1    12.50
# 2     4.50
# 3     6.00
# 4    17.74
# Name: Price, dtype: float64

# %%
#Scalling the X variables

from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler() 
dt_Scl = sc.fit_transform(X)
X=pd.DataFrame(dt_Scl, columns=X.columns)

# %%
X.head()
# Out:
#    Location      Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0  1.143658 -1.027139           0.145315  -1.570306      0.632529   -0.463672
# 1  1.481989  0.502161          -0.194369  -0.905771      0.632529   -0.463672
# 2 -1.224657 -0.721279          -0.139581   1.087831      0.632529   -0.463672
# 3 -1.224657 -0.415419           0.309678  -0.905771      0.632529   -0.463672
# 4 -0.886327 -0.109559          -0.197985  -0.905771     -1.580955    1.980149
#
#     Mileage    Engine     Power     Seats     Brand     Model
# 0  1.847799 -1.039653 -1.035066 -0.345849  0.331326  1.234893
# 1  0.335077 -0.065515  0.243242 -0.345849 -0.662260 -0.855564
# 2  0.014197 -0.704376 -0.461293 -0.345849 -0.786458 -0.058610
# 3  0.575192 -0.622642 -0.460166  2.135710  0.331326 -0.572831
# 4 -0.640661  0.578351  0.517541 -0.345849 -1.780044 -1.498781

# %%
# Spliting the DATA SET into Train and Test part -

from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=20)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)
reg.score(X_train, y_train)
# Out:
# 0.6951052154959211

# %%
reg.score(X_val, y_val)
# Out:
# 0.704083495712373

# %%
print('Score for Train Data: ', reg.score(X_train,y_train))
print('Score for Validation Data: ', reg.score(X_val,y_val))
# Out:
# Score for Train Data:  0.6951052154959211
# Score for Validation Data:  0.704083495712373

# %%
#We can use parameters or HyperParameters to change the the Score of model

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
import xgboost
regressor=xgboost.XGBRegressor()

booster=['gbtree','gblinear'] #Given Boosters are hyperparameters
base_score=[0.25,0.5,0.75,1]

# %%
## Hyper Parameter Optimization


n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
# Set up the random search with 4-fold cross validation
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=4)]: Done 250 out of 250 | elapsed:  5.4min finished
# /opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [06:41:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                           colsample_bylevel=1,
#                                           colsample_bynode=1,
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.75, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=5, min_child_weight=2, missing=None, n_estimators=1100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.75, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=5, min_child_weight=2, missing=None, n_estimators=1100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
regressor=xgboost.XGBRegressor(base_score=0.75, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=5, min_child_weight=2, missing=None, n_estimators=1100,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=3, scale_pos_weight=1, seed=None,
       silent=True, subsample=1, verbosity=1)

# %%
regressor.fit(X_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.75, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=5, min_child_weight=2, missing=None, n_estimators=1100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=3, scale_pos_weight=1, seed=None,
#              silent=True, subsample=1, verbosity=1)

# %%
y_pred=regressor.predict(Test3)

# %%
y_pred
# Out:
# array([35.823772, 34.041718, 34.061703, ..., 34.061703, 33.834988,
#        34.061703], dtype=float32)

# %%
data= pd.DataFrame(y_pred)

# %%
data.to_excel(r'UsedCarPrice.xlsx')
